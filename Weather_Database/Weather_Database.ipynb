# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import gmaps.datasets
from datetime import datetime

# Import the API key.
from config import g_key

# Import the random module.
import random 

# Import the NumPy module.
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the API key.
from config import weather_api_key

# %%
# Generate a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#Get the nearest city using the citipy module.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
#Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_description,
                          "Date": city_date})

        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | la ronge
# Processing Record 6 of Set 1 | bambanglipuro
# Processing Record 7 of Set 1 | yaan
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | casper
# Processing Record 10 of Set 1 | alyangula
# Processing Record 11 of Set 1 | yar-sale
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | bonthe
# Processing Record 14 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | samarai
# Processing Record 20 of Set 1 | moron
# Processing Record 21 of Set 1 | hasaki
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | miranda
# Processing Record 24 of Set 1 | iqaluit
# Processing Record 25 of Set 1 | do gonbadan
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | port lincoln
# Processing Record 28 of Set 1 | puerto colombia
# Processing Record 29 of Set 1 | norrtalje
# Processing Record 30 of Set 1 | mar del plata
# Processing Record 31 of Set 1 | avarua
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | henties bay
# Processing Record 34 of Set 1 | evensk
# Processing Record 35 of Set 1 | pangkalanbuun
# Processing Record 36 of Set 1 | woodward
# Processing Record 37 of Set 1 | katangli
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | aykhal
# Processing Record 40 of Set 1 | te anau
# Processing Record 41 of Set 1 | port hedland
# Processing Record 42 of Set 1 | florianopolis
# Processing Record 43 of Set 1 | pafos
# Processing Record 44 of Set 1 | komsomolskiy
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | olafsvik
# Processing Record 47 of Set 1 | puri
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | ponta do sol
# Processing Record 50 of Set 1 | rorvik
# Processing Record 1 of Set 2 | saldanha
# Processing Record 2 of Set 2 | nouadhibou
# Processing Record 3 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 2 | kattivakkam
# Processing Record 5 of Set 2 | vieste
# Processing Record 6 of Set 2 | viransehir
# Processing Record 7 of Set 2 | road town
# Processing Record 8 of Set 2 | takoradi
# Processing Record 9 of Set 2 | faya
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | klaksvik
# Processing Record 14 of Set 2 | chimoio
# Processing Record 15 of Set 2 | guarapari
# Processing Record 16 of Set 2 | korla
# Processing Record 17 of Set 2 | ponta delgada
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | ikere
# Processing Record 20 of Set 2 | mahebourg
# Processing Record 21 of Set 2 | pakokku
# Processing Record 22 of Set 2 | ancud
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | clyde river
# Processing Record 26 of Set 2 | port keats
# Processing Record 27 of Set 2 | dombarovskiy
# Processing Record 28 of Set 2 | benjamin constant
# Processing Record 29 of Set 2 | ambilobe
# Processing Record 30 of Set 2 | ribeira grande
# Processing Record 31 of Set 2 | saint-philippe
# Processing Record 32 of Set 2 | nanortalik
# Processing Record 33 of Set 2 | sirjan
# Processing Record 34 of Set 2 | touros
# Processing Record 35 of Set 2 | kapaa
# Processing Record 36 of Set 2 | sitka
# Processing Record 37 of Set 2 | san juan
# Processing Record 38 of Set 2 | kavieng
# Processing Record 39 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 2 | severo-kurilsk
# Processing Record 41 of Set 2 | dhidhdhoo
# Processing Record 42 of Set 2 | poum
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | qaqortoq
# Processing Record 46 of Set 2 | kozan
# Processing Record 47 of Set 2 | guerrero negro
# Processing Record 48 of Set 2 | lebu
# Processing Record 49 of Set 2 | ishigaki
# Processing Record 50 of Set 2 | pisco
# Processing Record 1 of Set 3 | cabildo
# Processing Record 2 of Set 3 | hilo
# Processing Record 3 of Set 3 | kouroussa
# Processing Record 4 of Set 3 | butler
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | ubala
# Processing Record 7 of Set 3 | alpena
# Processing Record 8 of Set 3 | walvis bay
# Processing Record 9 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 3 | barrow
# Processing Record 11 of Set 3 | zambezi
# Processing Record 12 of Set 3 | uddevalla
# Processing Record 13 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 3 | bonga
# Processing Record 15 of Set 3 | champerico
# Processing Record 16 of Set 3 | butaritari
# Processing Record 17 of Set 3 | bluff
# Processing Record 18 of Set 3 | loreto
# Processing Record 19 of Set 3 | loralai
# Processing Record 20 of Set 3 | vila velha
# Processing Record 21 of Set 3 | longyearbyen
# Processing Record 22 of Set 3 | vestmannaeyjar
# Processing Record 23 of Set 3 | ilulissat
# Processing Record 24 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 3 | kalmunai
# Processing Record 26 of Set 3 | caucaia
# Processing Record 27 of Set 3 | sobolevo
# Processing Record 28 of Set 3 | pawai
# Processing Record 29 of Set 3 | sulangan
# Processing Record 30 of Set 3 | port elizabeth
# Processing Record 31 of Set 3 | norman wells
# Processing Record 32 of Set 3 | mendi
# Processing Record 33 of Set 3 | nsoko
# Processing Record 34 of Set 3 | acapulco
# Processing Record 35 of Set 3 | ilkal
# Processing Record 36 of Set 3 | anna
# Processing Record 37 of Set 3 | harper
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | adolfo lopez mateos
# Processing Record 40 of Set 3 | dolgoye
# Processing Record 41 of Set 3 | kisarawe
# Processing Record 42 of Set 3 | nandigama
# Processing Record 43 of Set 3 | chokurdakh
# Processing Record 44 of Set 3 | cidreira
# Processing Record 45 of Set 3 | brae
# Processing Record 46 of Set 3 | upernavik
# Processing Record 47 of Set 3 | graaff-reinet
# Processing Record 48 of Set 3 | borkenes
# Processing Record 49 of Set 3 | borogontsy
# Processing Record 50 of Set 3 | terra santa
# Processing Record 1 of Set 4 | khatanga
# Processing Record 2 of Set 4 | ambon
# Processing Record 3 of Set 4 | coari
# Processing Record 4 of Set 4 | kodiak
# Processing Record 5 of Set 4 | toppenish
# Processing Record 6 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 4 | naryan-mar
# Processing Record 8 of Set 4 | belaya gora
# Processing Record 9 of Set 4 | kaitangata
# Processing Record 10 of Set 4 | namatanai
# Processing Record 11 of Set 4 | tilichiki
# Processing Record 12 of Set 4 | avera
# Processing Record 13 of Set 4 | andilamena
# Processing Record 14 of Set 4 | narva-joesuu
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 17 of Set 4 | bilma
# Processing Record 18 of Set 4 | souillac
# Processing Record 19 of Set 4 | altay
# Processing Record 20 of Set 4 | horsham
# Processing Record 21 of Set 4 | samana
# Processing Record 22 of Set 4 | tuatapere
# Processing Record 23 of Set 4 | castro
# Processing Record 24 of Set 4 | elko
# Processing Record 25 of Set 4 | san vicente
# Processing Record 26 of Set 4 | mezen
# Processing Record 27 of Set 4 | leningradskiy
# Processing Record 28 of Set 4 | padang
# Processing Record 29 of Set 4 | vao
# Processing Record 30 of Set 4 | kavaratti
# Processing Record 31 of Set 4 | araouane
# Processing Record 32 of Set 4 | ahipara
# Processing Record 33 of Set 4 | hualmay
# Processing Record 34 of Set 4 | chulman
# Processing Record 35 of Set 4 | sao felix do xingu
# Processing Record 36 of Set 4 | mount gambier
# Processing Record 37 of Set 4 | victoria
# Processing Record 38 of Set 4 | bethel
# Processing Record 39 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 4 | tagusao
# Processing Record 41 of Set 4 | krutikha
# Processing Record 42 of Set 4 | lagoa
# Processing Record 43 of Set 4 | talnakh
# Processing Record 44 of Set 4 | dicabisagan
# Processing Record 45 of Set 4 | toamasina
# Processing Record 46 of Set 4 | okandja
# City not found. Skipping...
# Processing Record 47 of Set 4 | port hardy
# Processing Record 48 of Set 4 | matara
# Processing Record 49 of Set 4 | bethanien
# Processing Record 50 of Set 4 | lobatse
# Processing Record 1 of Set 5 | atar
# Processing Record 2 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 5 | saskylakh
# Processing Record 4 of Set 5 | pangody
# Processing Record 5 of Set 5 | san cristobal
# Processing Record 6 of Set 5 | dikson
# Processing Record 7 of Set 5 | humberto de campos
# Processing Record 8 of Set 5 | xining
# Processing Record 9 of Set 5 | baijiantan
# Processing Record 10 of Set 5 | ville-marie
# Processing Record 11 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 12 of Set 5 | labuhan
# Processing Record 13 of Set 5 | linqu
# Processing Record 14 of Set 5 | oktyabrskiy
# Processing Record 15 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 5 | bud
# Processing Record 17 of Set 5 | ust-omchug
# Processing Record 18 of Set 5 | provideniya
# Processing Record 19 of Set 5 | gizo
# Processing Record 20 of Set 5 | thompson
# Processing Record 21 of Set 5 | ebano
# City not found. Skipping...
# Processing Record 22 of Set 5 | raga
# Processing Record 23 of Set 5 | huarmey
# Processing Record 24 of Set 5 | husavik
# Processing Record 25 of Set 5 | yakeshi
# Processing Record 26 of Set 5 | waipawa
# Processing Record 27 of Set 5 | pevek
# Processing Record 28 of Set 5 | lavrentiya
# Processing Record 29 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 5 | tasiilaq
# Processing Record 31 of Set 5 | abilene
# Processing Record 32 of Set 5 | ostrovnoy
# Processing Record 33 of Set 5 | faanui
# Processing Record 34 of Set 5 | north bend
# Processing Record 35 of Set 5 | karachi
# Processing Record 36 of Set 5 | camargo
# Processing Record 37 of Set 5 | erzin
# Processing Record 38 of Set 5 | bredasdorp
# Processing Record 39 of Set 5 | slave lake
# Processing Record 40 of Set 5 | malpe
# Processing Record 41 of Set 5 | kungurtug
# Processing Record 42 of Set 5 | san patricio
# Processing Record 43 of Set 5 | esperance
# Processing Record 44 of Set 5 | tonj
# Processing Record 45 of Set 5 | amapa
# Processing Record 46 of Set 5 | puerto escondido
# Processing Record 47 of Set 5 | yulara
# Processing Record 48 of Set 5 | gurupa
# Processing Record 49 of Set 5 | luderitz
# Processing Record 50 of Set 5 | dickinson
# Processing Record 1 of Set 6 | minot
# Processing Record 2 of Set 6 | svetlaya
# Processing Record 3 of Set 6 | high level
# Processing Record 4 of Set 6 | torbay
# Processing Record 5 of Set 6 | cayenne
# Processing Record 6 of Set 6 | los llanos de aridane
# Processing Record 7 of Set 6 | rio gallegos
# Processing Record 8 of Set 6 | sibu
# Processing Record 9 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 6 | novobirilyussy
# Processing Record 11 of Set 6 | chihuahua
# Processing Record 12 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 13 of Set 6 | kodinsk
# Processing Record 14 of Set 6 | saint george
# Processing Record 15 of Set 6 | napa
# Processing Record 16 of Set 6 | inhambane
# Processing Record 17 of Set 6 | saint anthony
# Processing Record 18 of Set 6 | asyut
# Processing Record 19 of Set 6 | ketchikan
# Processing Record 20 of Set 6 | surgut
# Processing Record 21 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 6 | dryden
# Processing Record 23 of Set 6 | flinders
# Processing Record 24 of Set 6 | arys
# Processing Record 25 of Set 6 | hofn
# Processing Record 26 of Set 6 | pangnirtung
# Processing Record 27 of Set 6 | solnechnyy
# Processing Record 28 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 29 of Set 6 | pochutla
# Processing Record 30 of Set 6 | aklavik
# Processing Record 31 of Set 6 | polunochnoye
# Processing Record 32 of Set 6 | lephepe
# City not found. Skipping...
# Processing Record 33 of Set 6 | shenjiamen
# Processing Record 34 of Set 6 | haines junction
# Processing Record 35 of Set 6 | panzhihua
# Processing Record 36 of Set 6 | bathsheba
# Processing Record 37 of Set 6 | berlevag
# Processing Record 38 of Set 6 | sur
# Processing Record 39 of Set 6 | dunedin
# Processing Record 40 of Set 6 | uyemskiy
# Processing Record 41 of Set 6 | sao filipe
# Processing Record 42 of Set 6 | chuy
# Processing Record 43 of Set 6 | sao gotardo
# Processing Record 44 of Set 6 | manhush
# Processing Record 45 of Set 6 | kosh-agach
# Processing Record 46 of Set 6 | georgetown
# Processing Record 47 of Set 6 | kimbe
# Processing Record 48 of Set 6 | alta floresta
# Processing Record 49 of Set 6 | new london
# Processing Record 50 of Set 6 | la asuncion
# Processing Record 1 of Set 7 | mehamn
# Processing Record 2 of Set 7 | wewak
# Processing Record 3 of Set 7 | bengkulu
# Processing Record 4 of Set 7 | port macquarie
# Processing Record 5 of Set 7 | bambous virieux
# Processing Record 6 of Set 7 | panguna
# Processing Record 7 of Set 7 | hami
# Processing Record 8 of Set 7 | honiara
# Processing Record 9 of Set 7 | nishihara
# Processing Record 10 of Set 7 | awbari
# Processing Record 11 of Set 7 | mungwi
# Processing Record 12 of Set 7 | morozovsk
# Processing Record 13 of Set 7 | forrest city
# Processing Record 14 of Set 7 | altamira
# Processing Record 15 of Set 7 | sola
# Processing Record 16 of Set 7 | mbamba
# Processing Record 17 of Set 7 | rio de janeiro
# Processing Record 18 of Set 7 | waraseoni
# Processing Record 19 of Set 7 | khani
# Processing Record 20 of Set 7 | quelimane
# Processing Record 21 of Set 7 | fortuna
# Processing Record 22 of Set 7 | shiyan
# Processing Record 23 of Set 7 | shelburne
# Processing Record 24 of Set 7 | charagua
# Processing Record 25 of Set 7 | mao
# Processing Record 26 of Set 7 | alofi
# Processing Record 27 of Set 7 | luganville
# Processing Record 28 of Set 7 | abu kamal
# Processing Record 29 of Set 7 | whyalla
# Processing Record 30 of Set 7 | farsund
# Processing Record 31 of Set 7 | dunmore town
# Processing Record 32 of Set 7 | namibe
# Processing Record 33 of Set 7 | namie
# Processing Record 34 of Set 7 | salina cruz
# Processing Record 35 of Set 7 | menongue
# Processing Record 36 of Set 7 | ugoofaaru
# Processing Record 37 of Set 7 | nome
# Processing Record 38 of Set 7 | saraland
# Processing Record 39 of Set 7 | chiscani
# Processing Record 40 of Set 7 | wamba
# Processing Record 41 of Set 7 | freeport
# Processing Record 42 of Set 7 | khrenovoye
# Processing Record 43 of Set 7 | northam
# Processing Record 44 of Set 7 | salalah
# Processing Record 45 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 7 | amahai
# Processing Record 47 of Set 7 | palmer
# Processing Record 48 of Set 7 | katete
# Processing Record 49 of Set 7 | muborak
# Processing Record 50 of Set 7 | tura
# Processing Record 1 of Set 8 | sinnamary
# Processing Record 2 of Set 8 | fremont
# Processing Record 3 of Set 8 | new iberia
# Processing Record 4 of Set 8 | lauterbach
# Processing Record 5 of Set 8 | santa rosalia
# Processing Record 6 of Set 8 | berdigestyakh
# Processing Record 7 of Set 8 | byron bay
# Processing Record 8 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 8 | sabha
# Processing Record 10 of Set 8 | olinda
# Processing Record 11 of Set 8 | kahului
# Processing Record 12 of Set 8 | kidal
# Processing Record 13 of Set 8 | kaka
# Processing Record 14 of Set 8 | stillwater
# Processing Record 15 of Set 8 | secovce
# Processing Record 16 of Set 8 | constitucion
# Processing Record 17 of Set 8 | palana
# Processing Record 18 of Set 8 | rawson
# Processing Record 19 of Set 8 | madimba
# Processing Record 20 of Set 8 | da nang
# Processing Record 21 of Set 8 | russell
# Processing Record 22 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 23 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 8 | ukiah
# Processing Record 25 of Set 8 | lorengau
# Processing Record 26 of Set 8 | rupert
# Processing Record 27 of Set 8 | north myrtle beach
# Processing Record 28 of Set 8 | noumea
# Processing Record 29 of Set 8 | riyadh
# Processing Record 30 of Set 8 | nampa
# Processing Record 31 of Set 8 | quatre cocos
# Processing Record 32 of Set 8 | geraldton
# Processing Record 33 of Set 8 | celestun
# Processing Record 34 of Set 8 | newport
# Processing Record 35 of Set 8 | saint-augustin
# Processing Record 36 of Set 8 | azad shahr
# Processing Record 37 of Set 8 | aloleng
# Processing Record 38 of Set 8 | kirakira
# Processing Record 39 of Set 8 | ierapetra
# Processing Record 40 of Set 8 | yeletskiy
# City not found. Skipping...
# Processing Record 41 of Set 8 | srandakan
# Processing Record 42 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 44 of Set 8 | zhigansk
# Processing Record 45 of Set 8 | bonavista
# Processing Record 46 of Set 8 | chicama
# Processing Record 47 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 8 | darhan
# Processing Record 49 of Set 8 | skelleftea
# Processing Record 50 of Set 8 | airai
# Processing Record 1 of Set 9 | shache
# Processing Record 2 of Set 9 | clarence town
# Processing Record 3 of Set 9 | sao miguel do araguaia
# Processing Record 4 of Set 9 | acari
# Processing Record 5 of Set 9 | baniachang
# Processing Record 6 of Set 9 | lasa
# Processing Record 7 of Set 9 | kyshtovka
# Processing Record 8 of Set 9 | zhigalovo
# Processing Record 9 of Set 9 | makakilo city
# Processing Record 10 of Set 9 | san bernardo
# Processing Record 11 of Set 9 | coolum beach
# Processing Record 12 of Set 9 | oranjestad
# Processing Record 13 of Set 9 | areosa
# Processing Record 14 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 9 | nsanje
# Processing Record 16 of Set 9 | rayon
# Processing Record 17 of Set 9 | lakes entrance
# Processing Record 18 of Set 9 | east liverpool
# Processing Record 19 of Set 9 | talcahuano
# Processing Record 20 of Set 9 | waterloo
# Processing Record 21 of Set 9 | manitouwadge
# Processing Record 22 of Set 9 | ayan
# Processing Record 23 of Set 9 | taoudenni
# Processing Record 24 of Set 9 | half moon bay
# Processing Record 25 of Set 9 | chegdomyn
# Processing Record 26 of Set 9 | goulburn
# Processing Record 27 of Set 9 | shirokiy
# Processing Record 28 of Set 9 | lakatoro
# Processing Record 29 of Set 9 | lethem
# Processing Record 30 of Set 9 | shingu
# Processing Record 31 of Set 9 | asfi
# Processing Record 32 of Set 9 | witu
# Processing Record 33 of Set 9 | karasjok
# Processing Record 34 of Set 9 | kenai
# Processing Record 35 of Set 9 | mayumba
# Processing Record 36 of Set 9 | beringovskiy
# Processing Record 37 of Set 9 | kommunisticheskiy
# Processing Record 38 of Set 9 | itarema
# Processing Record 39 of Set 9 | nelson bay
# Processing Record 40 of Set 9 | santona
# Processing Record 41 of Set 9 | khorixas
# Processing Record 42 of Set 9 | mandera
# Processing Record 43 of Set 9 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 44 of Set 9 | kloulklubed
# Processing Record 45 of Set 9 | kruisfontein
# Processing Record 46 of Set 9 | camacha
# Processing Record 47 of Set 9 | tuy hoa
# Processing Record 48 of Set 9 | gravelbourg
# Processing Record 49 of Set 9 | grindavik
# Processing Record 50 of Set 9 | port moresby
# Processing Record 1 of Set 10 | norfolk
# Processing Record 2 of Set 10 | gigmoto
# Processing Record 3 of Set 10 | cairns
# Processing Record 4 of Set 10 | lumphat
# Processing Record 5 of Set 10 | east london
# Processing Record 6 of Set 10 | port-gentil
# Processing Record 7 of Set 10 | winneba
# Processing Record 8 of Set 10 | bilibino
# Processing Record 9 of Set 10 | port blair
# Processing Record 10 of Set 10 | leshukonskoye
# Processing Record 11 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 10 | kleck
# City not found. Skipping...
# Processing Record 13 of Set 10 | jacksonville beach
# Processing Record 14 of Set 10 | laguna
# Processing Record 15 of Set 10 | bad liebenzell
# Processing Record 16 of Set 10 | jinan
# Processing Record 17 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 10 | abu samrah
# Processing Record 19 of Set 10 | sault sainte marie
# Processing Record 20 of Set 10 | yebaishou
# Processing Record 21 of Set 10 | halifax
# Processing Record 22 of Set 10 | saint-pierre
# Processing Record 23 of Set 10 | college
# Processing Record 24 of Set 10 | teneguiban
# City not found. Skipping...
# Processing Record 25 of Set 10 | san policarpo
# Processing Record 26 of Set 10 | lingao
# Processing Record 27 of Set 10 | portland
# Processing Record 28 of Set 10 | pyay
# Processing Record 29 of Set 10 | ucluelet
# Processing Record 30 of Set 10 | kontagora
# Processing Record 31 of Set 10 | cap-aux-meules
# Processing Record 32 of Set 10 | koumac
# Processing Record 33 of Set 10 | maarianhamina
# Processing Record 34 of Set 10 | greenfield
# Processing Record 35 of Set 10 | sistranda
# Processing Record 36 of Set 10 | porosozero
# Processing Record 37 of Set 10 | touho
# Processing Record 38 of Set 10 | itaituba
# Processing Record 39 of Set 10 | dawei
# Processing Record 40 of Set 10 | huangchuan
# Processing Record 41 of Set 10 | belmonte
# Processing Record 42 of Set 10 | maningrida
# Processing Record 43 of Set 10 | aksarka
# Processing Record 44 of Set 10 | gorontalo
# Processing Record 45 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 46 of Set 10 | bubaque
# Processing Record 47 of Set 10 | itaquyry
# Processing Record 48 of Set 10 | salekhard
# Processing Record 49 of Set 10 | katsuura
# Processing Record 50 of Set 10 | gao
# Processing Record 1 of Set 11 | rio grande
# Processing Record 2 of Set 11 | coquimbo
# Processing Record 3 of Set 11 | otradnoye
# Processing Record 4 of Set 11 | alice springs
# Processing Record 5 of Set 11 | olga
# Processing Record 6 of Set 11 | kudymkar
# Processing Record 7 of Set 11 | cururupu
# Processing Record 8 of Set 11 | coahuayana
# Processing Record 9 of Set 11 | yumen
# Processing Record 10 of Set 11 | shambu
# Processing Record 11 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 12 of Set 11 | jacareacanga
# Processing Record 13 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 11 | isangel
# Processing Record 15 of Set 11 | scottsbluff
# Processing Record 16 of Set 11 | naberera
# Processing Record 17 of Set 11 | tanete
# Processing Record 18 of Set 11 | saravan
# Processing Record 19 of Set 11 | rockhampton
# Processing Record 20 of Set 11 | totness
# Processing Record 21 of Set 11 | cap malheureux
# Processing Record 22 of Set 11 | inyonga
# Processing Record 23 of Set 11 | ipora
# Processing Record 24 of Set 11 | vardo
# Processing Record 25 of Set 11 | erenhot
# Processing Record 26 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 11 | suez
# Processing Record 28 of Set 11 | kangaatsiaq
# Processing Record 29 of Set 11 | tual
# Processing Record 30 of Set 11 | commerce
# Processing Record 31 of Set 11 | casa branca
# Processing Record 32 of Set 11 | mitsamiouli
# Processing Record 33 of Set 11 | trinidad
# Processing Record 34 of Set 11 | dalmau
# Processing Record 35 of Set 11 | belgrade
# Processing Record 36 of Set 11 | dingle
# Processing Record 37 of Set 11 | at-bashi
# Processing Record 38 of Set 11 | rebrikha
# Processing Record 39 of Set 11 | tezu
# Processing Record 40 of Set 11 | general roca
# Processing Record 41 of Set 11 | gloversville
# Processing Record 42 of Set 11 | riberalta
# Processing Record 43 of Set 11 | gashua
# Processing Record 44 of Set 11 | sembe
# Processing Record 45 of Set 11 | beyneu
# Processing Record 46 of Set 11 | rocha
# Processing Record 47 of Set 11 | pringsewu
# Processing Record 48 of Set 11 | boa vista
# Processing Record 49 of Set 11 | tazovskiy
# Processing Record 50 of Set 11 | aswan
# Processing Record 1 of Set 12 | kovur
# Processing Record 2 of Set 12 | waingapu
# Processing Record 3 of Set 12 | ginir
# Processing Record 4 of Set 12 | hailey
# Processing Record 5 of Set 12 | narsaq
# Processing Record 6 of Set 12 | haimen
# Processing Record 7 of Set 12 | talagang
# Processing Record 8 of Set 12 | lanigan
# Processing Record 9 of Set 12 | lafiagi
# Processing Record 10 of Set 12 | usinsk
# Processing Record 11 of Set 12 | sarangani
# Processing Record 12 of Set 12 | macusani
# Processing Record 13 of Set 12 | mayo
# Processing Record 14 of Set 12 | neyshabur
# Processing Record 15 of Set 12 | tessalit
# Processing Record 16 of Set 12 | fereydun kenar
# Processing Record 17 of Set 12 | lilongwe
# Processing Record 18 of Set 12 | hamilton
# Processing Record 19 of Set 12 | rafraf
# Processing Record 20 of Set 12 | nago
# Processing Record 21 of Set 12 | roma
# Processing Record 22 of Set 12 | acarau
# Processing Record 23 of Set 12 | baruun-urt
# Processing Record 24 of Set 12 | westport
# Processing Record 25 of Set 12 | sumoto
# Processing Record 26 of Set 12 | umm ruwabah
# City not found. Skipping...
# Processing Record 27 of Set 12 | sayat
# Processing Record 28 of Set 12 | gamba
# Processing Record 29 of Set 12 | marsh harbour
# Processing Record 30 of Set 12 | gualaquiza
# Processing Record 31 of Set 12 | voyvozh
# Processing Record 32 of Set 12 | presidencia roque saenz pena
# Processing Record 33 of Set 12 | pyapon
# Processing Record 34 of Set 12 | cherskiy
# Processing Record 35 of Set 12 | koppang
# Processing Record 36 of Set 12 | boende
# Processing Record 37 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 12 | eyl
# Processing Record 39 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 12 | itoman
# Processing Record 41 of Set 12 | anadyr
# Processing Record 42 of Set 12 | vigrestad
# Processing Record 43 of Set 12 | maceio
# Processing Record 44 of Set 12 | nantucket
# Processing Record 45 of Set 12 | synya
# Processing Record 46 of Set 12 | pedernales
# Processing Record 47 of Set 12 | glenwood springs
# Processing Record 48 of Set 12 | whitehaven
# Processing Record 49 of Set 12 | sisimiut
# Processing Record 50 of Set 12 | qasigiannguit
# Processing Record 1 of Set 13 | san andres
# Processing Record 2 of Set 13 | douglas
# Processing Record 3 of Set 13 | dipkarpaz
# City not found. Skipping...
# Processing Record 4 of Set 13 | vila
# Processing Record 5 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 13 | muramatsu
# Processing Record 7 of Set 13 | svetlogorsk
# Processing Record 8 of Set 13 | dawson creek
# Processing Record 9 of Set 13 | lakota
# Processing Record 10 of Set 13 | saint-joseph
# Processing Record 11 of Set 13 | praia
# Processing Record 12 of Set 13 | baishishan
# Processing Record 13 of Set 13 | okhotsk
# Processing Record 14 of Set 13 | khorramshahr
# Processing Record 15 of Set 13 | ixtapa
# Processing Record 16 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 17 of Set 13 | wilmington
# Processing Record 18 of Set 13 | ulladulla
# Processing Record 19 of Set 13 | princeton
# Processing Record 20 of Set 13 | cianorte
# Processing Record 21 of Set 13 | pacific grove
# Processing Record 22 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 23 of Set 13 | arica
# Processing Record 24 of Set 13 | ouargaye
# Processing Record 25 of Set 13 | mitu
# Processing Record 26 of Set 13 | naze
# Processing Record 27 of Set 13 | tabou
# Processing Record 28 of Set 13 | barinitas
# Processing Record 29 of Set 13 | chipinge
# Processing Record 30 of Set 13 | hay river
# Processing Record 31 of Set 13 | otane
# Processing Record 32 of Set 13 | grand gaube
# Processing Record 33 of Set 13 | emerald
# Processing Record 34 of Set 13 | madera
# Processing Record 35 of Set 13 | bereznik
# Processing Record 36 of Set 13 | hirara
# Processing Record 37 of Set 13 | lompoc
# Processing Record 38 of Set 13 | barcelos
# Processing Record 39 of Set 13 | francisco sa
# Processing Record 40 of Set 13 | prescott
# Processing Record 41 of Set 13 | lokoja
# Processing Record 42 of Set 13 | bucerias
# Processing Record 43 of Set 13 | flers
# Processing Record 44 of Set 13 | la ciotat
# Processing Record 45 of Set 13 | progreso
# Processing Record 46 of Set 13 | sambava
# Processing Record 47 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 48 of Set 13 | havelock
# Processing Record 49 of Set 13 | ust-ishim
# Processing Record 50 of Set 13 | billings
# Processing Record 1 of Set 14 | baoro
# Processing Record 2 of Set 14 | necochea
# Processing Record 3 of Set 14 | richards bay
# Processing Record 4 of Set 14 | tanout
# Processing Record 5 of Set 14 | brokopondo
# Processing Record 6 of Set 14 | jurm
# Processing Record 7 of Set 14 | bequimao
# Processing Record 8 of Set 14 | tonantins
# Processing Record 9 of Set 14 | kiunga
# Processing Record 10 of Set 14 | homer
# Processing Record 11 of Set 14 | port hawkesbury
# Processing Record 12 of Set 14 | vaitape
# Processing Record 13 of Set 14 | imbituba
# Processing Record 14 of Set 14 | kargasok
# Processing Record 15 of Set 14 | vikersund
# Processing Record 16 of Set 14 | mehran
# Processing Record 17 of Set 14 | shaoyang
# Processing Record 18 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 14 | springbok
# Processing Record 20 of Set 14 | pokhara
# Processing Record 21 of Set 14 | iquitos
# Processing Record 22 of Set 14 | manicore
# Processing Record 23 of Set 14 | aiquile
# Processing Record 24 of Set 14 | muros
# Processing Record 25 of Set 14 | luanda
# Processing Record 26 of Set 14 | paralimni
# Processing Record 27 of Set 14 | kota kinabalu
# Processing Record 28 of Set 14 | lamu
# Processing Record 29 of Set 14 | ginda
# Processing Record 30 of Set 14 | mankato
# Processing Record 31 of Set 14 | ossora
# Processing Record 32 of Set 14 | shwebo
# Processing Record 33 of Set 14 | yershov
# Processing Record 34 of Set 14 | hervey bay
# Processing Record 35 of Set 14 | buraydah
# Processing Record 36 of Set 14 | jabiru
# City not found. Skipping...
# Processing Record 37 of Set 14 | meulaboh
# Processing Record 38 of Set 14 | jinchang
# Processing Record 39 of Set 14 | strelka
# Processing Record 40 of Set 14 | kudahuvadhoo
# Processing Record 41 of Set 14 | bandarbeyla
# Processing Record 42 of Set 14 | yining
# Processing Record 43 of Set 14 | ottawa
# Processing Record 44 of Set 14 | benguela
# Processing Record 45 of Set 14 | opuwo
# Processing Record 46 of Set 14 | deniliquin
# Processing Record 47 of Set 14 | hambantota
# Processing Record 48 of Set 14 | harduaganj
# Processing Record 49 of Set 14 | coihaique
# Processing Record 50 of Set 14 | hokitika
# Processing Record 1 of Set 15 | westpunt
# City not found. Skipping...
# Processing Record 2 of Set 15 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 3 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 4 of Set 15 | meadow lake
# Processing Record 5 of Set 15 | iralaya
# Processing Record 6 of Set 15 | zephyrhills
# Processing Record 7 of Set 15 | lingdong
# Processing Record 8 of Set 15 | buala
# Processing Record 9 of Set 15 | balikpapan
# Processing Record 10 of Set 15 | sorland
# Processing Record 11 of Set 15 | rabo de peixe
# Processing Record 12 of Set 15 | pusad
# Processing Record 13 of Set 15 | pastos bons
# Processing Record 14 of Set 15 | margate
# Processing Record 15 of Set 15 | abalak
# Processing Record 16 of Set 15 | aktash
# Processing Record 17 of Set 15 | mahanoro
# Processing Record 18 of Set 15 | wad rawah
# Processing Record 19 of Set 15 | mandalgovi
# Processing Record 20 of Set 15 | san nicolas
# Processing Record 21 of Set 15 | taonan
# Processing Record 22 of Set 15 | ikot ekpene
# Processing Record 23 of Set 15 | cockburn town
# Processing Record 24 of Set 15 | kapasan
# Processing Record 25 of Set 15 | san quintin
# Processing Record 26 of Set 15 | plouzane
# Processing Record 27 of Set 15 | urumqi
# Processing Record 28 of Set 15 | dawlatabad
# Processing Record 29 of Set 15 | sabang
# Processing Record 30 of Set 15 | randvere
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Retrieve the following information from the API and add to Data Frame
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ushuaia -54.8000  -68.3000     46.40        76          40
# 1   Puerto Ayora  -0.7393  -90.3518     77.00        94          77
# 2      Jamestown  42.0970  -79.2353     23.00        68          90
# 3       La Ronge  55.1001 -105.2842    -20.20        63          39
# 4  Bambanglipuro  -7.9500  110.2833     80.55        76         100
# 5           Yaan   7.3833    8.5667     76.77        19          58
# 6   Punta Arenas -53.1500  -70.9167     48.20        61           0
# 7         Casper  42.8666 -106.3131     30.99        74          40
# 8      Alyangula -13.8483  136.4192     78.80        89          90
# 9       Yar-Sale  66.8333   70.8333    -17.54        88         100
#
#    Wind Speed Country Current Description                 Date
# 0       26.46      AR    scattered clouds  2021-02-06 01:20:08
# 1        4.00      EC       broken clouds  2021-02-06 01:21:48
# 2       17.27      US     overcast clouds  2021-02-06 01:22:57
# 3        9.22      CA    scattered clouds  2021-02-06 01:22:45
# 4        4.47      ID          light rain  2021-02-06 01:22:58
# 5        4.32      NG       broken clouds  2021-02-06 01:22:35
# 6       16.11      CL           clear sky  2021-02-06 01:22:59
# 7        5.75      US    scattered clouds  2021-02-06 01:22:59
# 8       16.11      AU       moderate rain  2021-02-06 01:23:00
# 9       10.33      RU     overcast clouds  2021-02-06 01:23:00

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ushuaia      AR -54.8000  -68.3000     46.40        76          40
# 1   Puerto Ayora      EC  -0.7393  -90.3518     77.00        94          77
# 2      Jamestown      US  42.0970  -79.2353     23.00        68          90
# 3       La Ronge      CA  55.1001 -105.2842    -20.20        63          39
# 4  Bambanglipuro      ID  -7.9500  110.2833     80.55        76         100
# 5           Yaan      NG   7.3833    8.5667     76.77        19          58
# 6   Punta Arenas      CL -53.1500  -70.9167     48.20        61           0
# 7         Casper      US  42.8666 -106.3131     30.99        74          40
# 8      Alyangula      AU -13.8483  136.4192     78.80        89          90
# 9       Yar-Sale      RU  66.8333   70.8333    -17.54        88         100
#
#    Wind Speed Current Description
# 0       26.46    scattered clouds
# 1        4.00       broken clouds
# 2       17.27     overcast clouds
# 3        9.22    scattered clouds
# 4        4.47          light rain
# 5        4.32       broken clouds
# 6       16.11           clear sky
# 7        5.75    scattered clouds
# 8       16.11       moderate rain
# 9       10.33     overcast clouds

# %%
#Save the new DataFrame as a CSV file - WeatherPy_Database.csv
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
